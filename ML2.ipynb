# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#loading the data frame
df= pd.read_csv("canada_per_capita_income.csv")

# %%
# display data frame
df
# Out:
#     year  perCapitaIncome
# 0   1970      3399.299037
# 1   1971      3768.297935
# 2   1972      4251.175484
# 3   1973      4804.463248
# 4   1974      5576.514583
# 5   1975      5998.144346
# 6   1976      7062.131392
# 7   1977      7100.126170
# 8   1978      7247.967035
# 9   1979      7602.912681
# 10  1980      8355.968120
# 11  1981      9434.390652
# 12  1982      9619.438377
# 13  1983     10416.536590
# 14  1984     10790.328720
# 15  1985     11018.955850
# 16  1986     11482.891530
# 17  1987     12974.806620
# 18  1988     15080.283450
# 19  1989     16426.725480
# 20  1990     16838.673200
# 21  1991     17266.097690
# 22  1992     16412.083090
# 23  1993     15875.586730
# 24  1994     15755.820270
# 25  1995     16369.317250
# 26  1996     16699.826680
# 27  1997     17310.757750
# 28  1998     16622.671870
# 29  1999     17581.024140
# 30  2000     18987.382410
# 31  2001     18601.397240
# 32  2002     19232.175560
# 33  2003     22739.426280
# 34  2004     25719.147150
# 35  2005     29198.055690
# 36  2006     32738.262900
# 37  2007     36144.481220
# 38  2008     37446.486090
# 39  2009     32755.176820
# 40  2010     38420.522890
# 41  2011     42334.711210
# 42  2012     42665.255970
# 43  2013     42676.468370
# 44  2014     41039.893600
# 45  2015     35175.188980
# 46  2016     34229.193630

# %%
#plotting a scatter plot to get an idea of the distribution
# %matplotlib inline
#labellling x and y axis
plt.xlabel('year')
plt.ylabel('perCapitaIncome (US$)')
#df.area is plotted against df.price
plt.scatter(df.year,df.perCapitaIncome, color='red',marker='+')

# %%
#creating linear reg obj called reg
#since we have already imported lin mod
reg= linear_model.LinearRegression()
# now we hav to fit the data meaning you're training the linear reg model using the available data points
#there will be 2 arguments.
#first has to be a 2D array so our dataframe is given here and second arg is the y axis i.e.. price
reg.fit(df[['year']],df.perCapitaIncome)
# Out:
# LinearRegression()

# %%
#predicitng the perCapitaIncome in the year of 2017
reg.predict([[2017]])
# Out:
# array([38803.29886875])

# %%
#create a new csv with year and it's predicitve
#first read the file
df2= pd.read_csv("canadaPredict.csv")
df2.head(3) #or df2
# Out:
#    year
# 0  2017
# 1  2018
# 2  2019

# %%
#Now using reg model, predict the prices
#storing the prices in var p
p=reg.predict(df2)

# %%
# to creat a new col in the dataframe=== df2['prices']
# and assign p
df2['prices']=p

# %%
df2
# Out:
#     year        prices
# 0   2017  38803.298869
# 1   2018  39631.763944
# 2   2019  40460.229019
# 3   2020  41288.694094
# 4   2021  42117.159170
# 5   2022  42945.624245
# 6   2023  43774.089320
# 7   2024  44602.554395
# 8   2025  45431.019471
# 9   2026  46259.484546
# 10  2027  47087.949621
# 11  2028  47916.414696
# 12  2029  48744.879771

# %%
# use to_csv method to export the dataframe into a csv file
#so a new file name prediction.csv is created
df2.to_csv("canada_per_capita_income_predicition.csv") #now this is with index
# if you dont want it with an index then df2.to_csv("prediction.csv", index=False)
